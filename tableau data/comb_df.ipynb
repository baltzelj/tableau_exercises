# %%
import pandas as pd

# %%
jan_data = pd.read_csv("JC-202401-citibike-tripdata.csv")
feb_data = pd.read_csv("JC-202402-citibike-tripdata.csv")
mar_data = pd.read_csv("JC-202403-citibike-tripdata.csv")
apr_data = pd.read_csv("JC-202404-citibike-tripdata.csv")

# %%
jan_df = pd.DataFrame(jan_data)
feb_df = pd.DataFrame(feb_data)
mar_df = pd.DataFrame(mar_data)
apr_df = pd.DataFrame(apr_data)

# %%
bike_data = [jan_df, feb_df, mar_df, apr_df]

bike_df = pd.concat(bike_data)

# %%
print(bike_df.shape)
print(bike_df.columns)
# Out:
# (250971, 13)
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
bike_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      0744109F13385D1D  electric_bike  2024-01-15 15:18:07
# 1      B1488BFEF9118000   classic_bike  2024-01-13 15:32:50
# 2      95A2FE8E51B4C836   classic_bike  2024-01-19 13:11:00
# 3      95D9AFF6A1652DC1   classic_bike  2024-01-23 07:03:49
# 4      5F7408988A83B1B3   classic_bike  2024-01-01 16:46:10
# ...                 ...            ...                  ...
# 79111  CE90C772574D5E70  electric_bike  2024-04-21 15:56:52
# 79112  70D59D4F56BAA44C  electric_bike  2024-04-21 16:11:20
# 79113  919C8DE40AC18B29  electric_bike  2024-04-26 17:48:39
# 79114  46D5752D4AFF2E1B   classic_bike  2024-04-16 13:20:32
# 79115  F79D0248A8361A64  electric_bike  2024-04-07 14:11:42
#
#                   ended_at start_station_name start_station_id  \
# 0      2024-01-15 15:32:44       Morris Canal            JC072
# 1      2024-01-13 15:36:18  JC Medical Center            JC110
# ...

# %%
bike_df.to_csv("bike_dataframe.csv")
